# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 788

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests as req

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Tool Box to fix errors
#city_url = url + "&q=" + city
#city_weather = req.get(city_url).json()
#z = city_weather["weather"]
#descrip = z[0]["description"]
#descrip

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1   #50 cities per set

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = req.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_min_temp = city_weather["main"]["temp_min"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]        
        
        # Parse out weather description
        z = city_weather["weather"]
        city_description = z[0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')      
            
        # Append the city information into the city_data list
        city_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Min Temp": city_min_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Current Description": city_description,
            "Country": city_country,
            "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lazaro cardenas
# Processing Record 2 of Set 1 | sao gabriel da cachoeira
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | venado tuerto
# Processing Record 6 of Set 1 | asyut
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | saint-francois
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | lugovoy
# Processing Record 17 of Set 1 | broken hill
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | okhotsk
# Processing Record 20 of Set 1 | katherine
# Processing Record 21 of Set 1 | los llanos de aridane
# Processing Record 22 of Set 1 | vao
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | touros
# Processing Record 30 of Set 1 | yako
# Processing Record 31 of Set 1 | dingle
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | tari
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | darab
# Processing Record 36 of Set 1 | saint george
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 1 | talakan
# Processing Record 42 of Set 1 | pangkalanbuun
# Processing Record 43 of Set 1 | srednekolymsk
# Processing Record 44 of Set 1 | sao felix do xingu
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | nampa
# Processing Record 49 of Set 1 | cedar rapids
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | slave lake
# Processing Record 2 of Set 2 | sheksna
# Processing Record 3 of Set 2 | altay
# Processing Record 4 of Set 2 | deputatskiy
# Processing Record 5 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 2 | tamandare
# Processing Record 7 of Set 2 | aklavik
# Processing Record 8 of Set 2 | shimoda
# Processing Record 9 of Set 2 | susanville
# Processing Record 10 of Set 2 | japura
# Processing Record 11 of Set 2 | nuuk
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | half moon bay
# Processing Record 14 of Set 2 | great yarmouth
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | salalah
# Processing Record 18 of Set 2 | trairi
# Processing Record 19 of Set 2 | coahuayana
# Processing Record 20 of Set 2 | komsomolskiy
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | okakarara
# Processing Record 23 of Set 2 | shizuishan
# Processing Record 24 of Set 2 | beipiao
# Processing Record 25 of Set 2 | rio gallegos
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | sulangan
# Processing Record 28 of Set 2 | acajutla
# Processing Record 29 of Set 2 | hammonton
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | la seyne-sur-mer
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | ashqelon
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | pulandian
# Processing Record 36 of Set 2 | cockburn town
# Processing Record 37 of Set 2 | mount isa
# Processing Record 38 of Set 2 | muhos
# Processing Record 39 of Set 2 | omboue
# Processing Record 40 of Set 2 | rio grande
# Processing Record 41 of Set 2 | porto belo
# Processing Record 42 of Set 2 | mackay
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | quatre cocos
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 2 | velikie luki
# City not found. Skipping...
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | north bend
# Processing Record 1 of Set 3 | bilibino
# Processing Record 2 of Set 3 | kirakira
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | shubarshi
# Processing Record 5 of Set 3 | richards bay
# Processing Record 6 of Set 3 | lompoc
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | najran
# Processing Record 11 of Set 3 | santa catarina de tepehuanes
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | bambous virieux
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | suzun
# Processing Record 18 of Set 3 | ahipara
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | albany
# Processing Record 21 of Set 3 | roma
# Processing Record 22 of Set 3 | pemba
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | san bartolome de tirajana
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | antsohihy
# Processing Record 27 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 3 | the pas
# Processing Record 29 of Set 3 | kavaratti
# Processing Record 30 of Set 3 | ossora
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | livramento
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | henties bay
# Processing Record 38 of Set 3 | kamwenge
# Processing Record 39 of Set 3 | husavik
# Processing Record 40 of Set 3 | sabang
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | labuhan
# Processing Record 43 of Set 3 | bolitoc
# Processing Record 44 of Set 3 | ayr
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | cabedelo
# Processing Record 47 of Set 3 | doha
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | varjota
# Processing Record 1 of Set 4 | whitehorse
# Processing Record 2 of Set 4 | raudeberg
# Processing Record 3 of Set 4 | usinsk
# Processing Record 4 of Set 4 | qurayyat
# Processing Record 5 of Set 4 | coihaique
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | tingo maria
# Processing Record 9 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | aginskoye
# Processing Record 12 of Set 4 | sorong
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | kargasok
# Processing Record 15 of Set 4 | turukhansk
# Processing Record 16 of Set 4 | nhulunbuy
# Processing Record 17 of Set 4 | morant bay
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 20 of Set 4 | road town
# Processing Record 21 of Set 4 | ostrovnoy
# Processing Record 22 of Set 4 | vieques
# Processing Record 23 of Set 4 | thompson
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | kapaa
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | vila velha
# Processing Record 30 of Set 4 | truro
# Processing Record 31 of Set 4 | nam som
# Processing Record 32 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | lavrentiya
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | banyo
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | coquimbo
# Processing Record 40 of Set 4 | soyo
# Processing Record 41 of Set 4 | delijan
# Processing Record 42 of Set 4 | codrington
# Processing Record 43 of Set 4 | pravokumskoye
# Processing Record 44 of Set 4 | vila franca do campo
# Processing Record 45 of Set 4 | medicine hat
# Processing Record 46 of Set 4 | ryazanskaya
# Processing Record 47 of Set 4 | tres arroyos
# Processing Record 48 of Set 4 | nizwa
# Processing Record 49 of Set 4 | pachino
# Processing Record 50 of Set 4 | telma
# Processing Record 1 of Set 5 | honiara
# Processing Record 2 of Set 5 | riyadh
# Processing Record 3 of Set 5 | sur
# Processing Record 4 of Set 5 | gurupa
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | peyima
# Processing Record 7 of Set 5 | makubetsu
# Processing Record 8 of Set 5 | walvis bay
# Processing Record 9 of Set 5 | mazara del vallo
# Processing Record 10 of Set 5 | zhezkazgan
# Processing Record 11 of Set 5 | port hardy
# Processing Record 12 of Set 5 | necochea
# Processing Record 13 of Set 5 | tutoia
# Processing Record 14 of Set 5 | ilanskiy
# Processing Record 15 of Set 5 | cuautlapan
# Processing Record 16 of Set 5 | biak
# Processing Record 17 of Set 5 | ozernovskiy
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | krasnovishersk
# Processing Record 20 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 5 | morros
# Processing Record 22 of Set 5 | maceio
# Processing Record 23 of Set 5 | ararat
# Processing Record 24 of Set 5 | atar
# Processing Record 25 of Set 5 | kodinsk
# Processing Record 26 of Set 5 | skelleftea
# Processing Record 27 of Set 5 | pangnirtung
# Processing Record 28 of Set 5 | caborca
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | pitea
# Processing Record 31 of Set 5 | zhigansk
# Processing Record 32 of Set 5 | yeppoon
# Processing Record 33 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 5 | mehamn
# Processing Record 35 of Set 5 | polewali
# Processing Record 36 of Set 5 | solnechnyy
# Processing Record 37 of Set 5 | brownsville
# Processing Record 38 of Set 5 | ketchikan
# Processing Record 39 of Set 5 | svetlogorsk
# Processing Record 40 of Set 5 | gat
# Processing Record 41 of Set 5 | sabha
# Processing Record 42 of Set 5 | bari sadri
# Processing Record 43 of Set 5 | portland
# Processing Record 44 of Set 5 | daru
# Processing Record 45 of Set 5 | eureka
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | juneau
# Processing Record 48 of Set 5 | yerofey pavlovich
# Processing Record 49 of Set 5 | sao filipe
# Processing Record 50 of Set 5 | clyde river

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 719

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Min Temp  Humidity  Cloudiness  \
# 0  Porto Seguro -16.4497  -39.0647     73.92     73.92       100         100
# 1        Abalak  58.1286   68.5944     49.69     49.69        61         100
# 2      Kandrian  -6.2167  149.5500     79.50     79.50        82          91
# 3  Saint George  37.1041 -113.5841     59.25     55.44        50           0
# 4        Atuona  -9.8000 -139.0333     80.83     80.83        80          55
# 5      Ust-Nera  64.5667  143.2000     19.72     19.72        94         100
# 6  Punta Arenas -53.1500  -70.9167     44.71     44.11        61           0
# 7        Nabire  -3.3667  135.4833     77.22     77.22        89         100
# 8        Albany  42.6001  -73.9662     59.63     51.26        74         100
# 9        Aykhal  66.0000  111.5000     17.38     17.38        91         100
#
#    Wind Speed Current Description Country                 Date
# 0        5.75                mist      BR  2023-04-22 13:56:14
# 1        5.03     overcast clouds      RU  2023-04-22 13:56:14
# 2        4.99     overcast clouds      PG  2023-04-22 13:56:14
# 3        5.75           clear sky      US  2023-04-22 13:51:25
# 4       14.05          light rain      PF  2023-04-22 13:55:02
# 5        3.20     overcast clouds      RU  2023-04-22 13:56:15
# 6       17.27           clear sky      CL  2023-04-22 13:50:40
# 7        1.74     overcast clouds      ID  2023-04-22 13:56:15
# 8        3.00     overcast clouds      US  2023-04-22 13:50:45
# 9        9.28     overcast clouds      RU  2023-04-22 13:56:15

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Min Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Min Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Porto Seguro      BR  2023-04-22 13:56:14 -16.4497  -39.0647     73.92
# 1        Abalak      RU  2023-04-22 13:56:14  58.1286   68.5944     49.69
# 2      Kandrian      PG  2023-04-22 13:56:14  -6.2167  149.5500     79.50
# 3  Saint George      US  2023-04-22 13:51:25  37.1041 -113.5841     59.25
# 4        Atuona      PF  2023-04-22 13:55:02  -9.8000 -139.0333     80.83
# 5      Ust-Nera      RU  2023-04-22 13:56:15  64.5667  143.2000     19.72
# 6  Punta Arenas      CL  2023-04-22 13:50:40 -53.1500  -70.9167     44.71
# 7        Nabire      ID  2023-04-22 13:56:15  -3.3667  135.4833     77.22
# 8        Albany      US  2023-04-22 13:50:45  42.6001  -73.9662     59.63
# 9        Aykhal      RU  2023-04-22 13:56:15  66.0000  111.5000     17.38
#
#    Min Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     73.92       100         100        5.75                mist
# 1     49.69        61         100        5.03     overcast clouds
# 2     79.50        82          91        4.99     overcast clouds
# 3     55.44        50           0        5.75           clear sky
# 4     80.83        80          55       14.05          light rain
# 5     19.72        94         100        3.20     overcast clouds
# 6     44.11        61           0       17.27           clear sky
# 7     77.22        89         100        1.74     overcast clouds
# 8     51.26        74         100        3.00     overcast clouds
# 9     17.38        91         100        9.28     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Min Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
