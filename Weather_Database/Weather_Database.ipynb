# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 788

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests as req

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Tool Box to fix errors
#city_url = url + "&q=" + city
#city_weather = req.get(city_url).json()
#z = city_weather["weather"]
#descrip = z[0]["description"]
#descrip

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1   #50 cities per set

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = req.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_min_temp = city_weather["main"]["temp_min"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]        
        
        # Parse out weather description
        z = city_weather["weather"]
        city_description = z[0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')      
            
        # Append the city information into the city_data list
        city_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Min Temp": city_min_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Current Description": city_description,
            "Country": city_country,
            "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lazaro cardenas
# Processing Record 2 of Set 1 | sao gabriel da cachoeira
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | venado tuerto
# Processing Record 6 of Set 1 | asyut
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | saint-francois
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | lugovoy
# Processing Record 17 of Set 1 | broken hill
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | okhotsk
# Processing Record 20 of Set 1 | katherine
# Processing Record 21 of Set 1 | los llanos de aridane
# Processing Record 22 of Set 1 | vao
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | touros
# Processing Record 30 of Set 1 | yako
# Processing Record 31 of Set 1 | dingle
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | tari
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | darab
# Processing Record 36 of Set 1 | saint george
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 1 | talakan
# Processing Record 42 of Set 1 | pangkalanbuun
# Processing Record 43 of Set 1 | srednekolymsk
# Processing Record 44 of Set 1 | sao felix do xingu
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | nampa
# Processing Record 49 of Set 1 | cedar rapids
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | slave lake
# Processing Record 2 of Set 2 | sheksna
# Processing Record 3 of Set 2 | altay
# Processing Record 4 of Set 2 | deputatskiy
# Processing Record 5 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 2 | tamandare
# Processing Record 7 of Set 2 | aklavik
# Processing Record 8 of Set 2 | shimoda
# Processing Record 9 of Set 2 | susanville
# Processing Record 10 of Set 2 | japura
# Processing Record 11 of Set 2 | nuuk
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | half moon bay
# Processing Record 14 of Set 2 | great yarmouth
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | salalah
# Processing Record 18 of Set 2 | trairi
# Processing Record 19 of Set 2 | coahuayana
# Processing Record 20 of Set 2 | komsomolskiy
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | okakarara
# Processing Record 23 of Set 2 | shizuishan
# Processing Record 24 of Set 2 | beipiao
# Processing Record 25 of Set 2 | rio gallegos
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | sulangan
# Processing Record 28 of Set 2 | acajutla
# Processing Record 29 of Set 2 | hammonton
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | la seyne-sur-mer
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | ashqelon
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | pulandian
# Processing Record 36 of Set 2 | cockburn town
# Processing Record 37 of Set 2 | mount isa
# Processing Record 38 of Set 2 | muhos
# Processing Record 39 of Set 2 | omboue
# Processing Record 40 of Set 2 | rio grande
# Processing Record 41 of Set 2 | porto belo
# Processing Record 42 of Set 2 | mackay
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | quatre cocos
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 2 | velikie luki
# City not found. Skipping...
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | north bend
# Processing Record 1 of Set 3 | bilibino
# Processing Record 2 of Set 3 | kirakira
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | shubarshi
# Processing Record 5 of Set 3 | richards bay
# Processing Record 6 of Set 3 | lompoc
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | najran
# Processing Record 11 of Set 3 | santa catarina de tepehuanes
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | bambous virieux
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | suzun
# Processing Record 18 of Set 3 | ahipara
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | albany
# Processing Record 21 of Set 3 | roma
# Processing Record 22 of Set 3 | pemba
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | san bartolome de tirajana
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | antsohihy
# Processing Record 27 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 3 | the pas
# Processing Record 29 of Set 3 | kavaratti
# Processing Record 30 of Set 3 | ossora
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | livramento
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | henties bay
# Processing Record 38 of Set 3 | kamwenge
# Processing Record 39 of Set 3 | husavik
# Processing Record 40 of Set 3 | sabang
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | labuhan
# Processing Record 43 of Set 3 | bolitoc
# Processing Record 44 of Set 3 | ayr
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | cabedelo
# Processing Record 47 of Set 3 | doha
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | varjota
# Processing Record 1 of Set 4 | whitehorse
# Processing Record 2 of Set 4 | raudeberg
# Processing Record 3 of Set 4 | usinsk
# Processing Record 4 of Set 4 | qurayyat
# Processing Record 5 of Set 4 | coihaique
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | tingo maria
# Processing Record 9 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | aginskoye
# Processing Record 12 of Set 4 | sorong
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | kargasok
# Processing Record 15 of Set 4 | turukhansk
# Processing Record 16 of Set 4 | nhulunbuy
# Processing Record 17 of Set 4 | morant bay
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 20 of Set 4 | road town
# Processing Record 21 of Set 4 | ostrovnoy
# Processing Record 22 of Set 4 | vieques
# Processing Record 23 of Set 4 | thompson
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | kapaa
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | vila velha
# Processing Record 30 of Set 4 | truro
# Processing Record 31 of Set 4 | nam som
# Processing Record 32 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | lavrentiya
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | banyo
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | coquimbo
# Processing Record 40 of Set 4 | soyo
# Processing Record 41 of Set 4 | delijan
# Processing Record 42 of Set 4 | codrington
# Processing Record 43 of Set 4 | pravokumskoye
# Processing Record 44 of Set 4 | vila franca do campo
# Processing Record 45 of Set 4 | medicine hat
# Processing Record 46 of Set 4 | ryazanskaya
# Processing Record 47 of Set 4 | tres arroyos
# Processing Record 48 of Set 4 | nizwa
# Processing Record 49 of Set 4 | pachino
# Processing Record 50 of Set 4 | telma
# Processing Record 1 of Set 5 | honiara
# Processing Record 2 of Set 5 | riyadh
# Processing Record 3 of Set 5 | sur
# Processing Record 4 of Set 5 | gurupa
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | peyima
# Processing Record 7 of Set 5 | makubetsu
# Processing Record 8 of Set 5 | walvis bay
# Processing Record 9 of Set 5 | mazara del vallo
# Processing Record 10 of Set 5 | zhezkazgan
# Processing Record 11 of Set 5 | port hardy
# Processing Record 12 of Set 5 | necochea
# Processing Record 13 of Set 5 | tutoia
# Processing Record 14 of Set 5 | ilanskiy
# Processing Record 15 of Set 5 | cuautlapan
# Processing Record 16 of Set 5 | biak
# Processing Record 17 of Set 5 | ozernovskiy
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | krasnovishersk
# Processing Record 20 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 5 | morros
# Processing Record 22 of Set 5 | maceio
# Processing Record 23 of Set 5 | ararat
# Processing Record 24 of Set 5 | atar
# Processing Record 25 of Set 5 | kodinsk
# Processing Record 26 of Set 5 | skelleftea
# Processing Record 27 of Set 5 | pangnirtung
# Processing Record 28 of Set 5 | caborca
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | pitea
# Processing Record 31 of Set 5 | zhigansk
# Processing Record 32 of Set 5 | yeppoon
# Processing Record 33 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 5 | mehamn
# Processing Record 35 of Set 5 | polewali
# Processing Record 36 of Set 5 | solnechnyy
# Processing Record 37 of Set 5 | brownsville
# Processing Record 38 of Set 5 | ketchikan
# Processing Record 39 of Set 5 | svetlogorsk
# Processing Record 40 of Set 5 | gat
# Processing Record 41 of Set 5 | sabha
# Processing Record 42 of Set 5 | bari sadri
# Processing Record 43 of Set 5 | portland
# Processing Record 44 of Set 5 | daru
# Processing Record 45 of Set 5 | eureka
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | juneau
# Processing Record 48 of Set 5 | yerofey pavlovich
# Processing Record 49 of Set 5 | sao filipe
# Processing Record 50 of Set 5 | clyde river
# Processing Record 1 of Set 6 | zalantun
# Processing Record 2 of Set 6 | merrill
# Processing Record 3 of Set 6 | pombas
# Processing Record 4 of Set 6 | khash
# Processing Record 5 of Set 6 | bosobolo
# Processing Record 6 of Set 6 | iqaluit
# Processing Record 7 of Set 6 | sambava
# Processing Record 8 of Set 6 | alyangula
# Processing Record 9 of Set 6 | san patricio
# Processing Record 10 of Set 6 | atambua
# Processing Record 11 of Set 6 | harper
# Processing Record 12 of Set 6 | katsuura
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | bosaso
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 6 | san benito
# Processing Record 18 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 6 | sola
# Processing Record 20 of Set 6 | rosetta
# Processing Record 21 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | lebu
# Processing Record 24 of Set 6 | saldanha
# Processing Record 25 of Set 6 | vardo
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | santa maria
# Processing Record 28 of Set 6 | changli
# Processing Record 29 of Set 6 | zhurivka
# Processing Record 30 of Set 6 | casambalangan
# Processing Record 31 of Set 6 | moroni
# Processing Record 32 of Set 6 | cap malheureux
# Processing Record 33 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 6 | zaysan
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | ferme-neuve
# Processing Record 37 of Set 6 | ilukste
# Processing Record 38 of Set 6 | kanniyakumari
# Processing Record 39 of Set 6 | antofagasta
# Processing Record 40 of Set 6 | kharhial
# Processing Record 41 of Set 6 | hobyo
# Processing Record 42 of Set 6 | quelimane
# Processing Record 43 of Set 6 | cascais
# Processing Record 44 of Set 6 | kupang
# Processing Record 45 of Set 6 | abay
# Processing Record 46 of Set 6 | arlit
# Processing Record 47 of Set 6 | ust-kuyga
# Processing Record 48 of Set 6 | gigmoto
# Processing Record 49 of Set 6 | egvekinot
# Processing Record 50 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 1 of Set 7 | leh
# Processing Record 2 of Set 7 | geraldton
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 | sa kaeo
# Processing Record 5 of Set 7 | dakar
# Processing Record 6 of Set 7 | athens
# Processing Record 7 of Set 7 | talen
# Processing Record 8 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | vangaindrano
# Processing Record 11 of Set 7 | linares
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | placido de castro
# Processing Record 14 of Set 7 | samarai
# Processing Record 15 of Set 7 | maloy
# Processing Record 16 of Set 7 | bathsheba
# Processing Record 17 of Set 7 | zumarraga
# Processing Record 18 of Set 7 | selje
# Processing Record 19 of Set 7 | marsa matruh
# Processing Record 20 of Set 7 | caravelas
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | navlya
# Processing Record 24 of Set 7 | asau
# Processing Record 25 of Set 7 | rocha
# Processing Record 26 of Set 7 | mayor pablo lagerenza
# Processing Record 27 of Set 7 | tuatapere
# Processing Record 28 of Set 7 | pahrump
# Processing Record 29 of Set 7 | nanortalik
# Processing Record 30 of Set 7 | margate
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | rognan
# Processing Record 33 of Set 7 | eydhafushi
# Processing Record 34 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | chokurdakh
# Processing Record 36 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 7 | vieste
# Processing Record 38 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 39 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 7 | hasaki
# Processing Record 41 of Set 7 | barwaha
# City not found. Skipping...
# Processing Record 42 of Set 7 | kautokeino
# Processing Record 43 of Set 7 | nome
# Processing Record 44 of Set 7 | bitung
# Processing Record 45 of Set 7 | pitimbu
# Processing Record 46 of Set 7 | usogorsk
# Processing Record 47 of Set 7 | esperance
# Processing Record 48 of Set 7 | alvaraes
# Processing Record 49 of Set 7 | kingman
# Processing Record 50 of Set 7 | kununurra
# Processing Record 1 of Set 8 | olafsvik
# Processing Record 2 of Set 8 | arman
# Processing Record 3 of Set 8 | maniwaki
# Processing Record 4 of Set 8 | olinda
# Processing Record 5 of Set 8 | tazovskiy
# Processing Record 6 of Set 8 | berlevag
# Processing Record 7 of Set 8 | bombay
# Processing Record 8 of Set 8 | tynda
# Processing Record 9 of Set 8 | yeniseysk
# Processing Record 10 of Set 8 | anadyr
# Processing Record 11 of Set 8 | tagab
# Processing Record 12 of Set 8 | mana
# Processing Record 13 of Set 8 | linapacan
# City not found. Skipping...
# Processing Record 14 of Set 8 | cururupu
# Processing Record 15 of Set 8 | kavieng
# Processing Record 16 of Set 8 | todos santos
# Processing Record 17 of Set 8 | beloha
# Processing Record 18 of Set 8 | umuahia
# Processing Record 19 of Set 8 | belyy yar
# Processing Record 20 of Set 8 | provideniya
# Processing Record 21 of Set 8 | aksarka
# Processing Record 22 of Set 8 | gimli
# Processing Record 23 of Set 8 | grindavik
# Processing Record 24 of Set 8 | isangel
# Processing Record 25 of Set 8 | saint-pierre
# Processing Record 26 of Set 8 | mafinga
# Processing Record 27 of Set 8 | zambezi
# Processing Record 28 of Set 8 | estevan
# Processing Record 29 of Set 8 | college
# Processing Record 30 of Set 8 | torbay
# Processing Record 31 of Set 8 | bukama
# Processing Record 32 of Set 8 | camargo
# Processing Record 33 of Set 8 | naze
# Processing Record 34 of Set 8 | bereda
# Processing Record 35 of Set 8 | namibe
# Processing Record 36 of Set 8 | ust-tsilma
# Processing Record 37 of Set 8 | korla
# Processing Record 38 of Set 8 | pevek
# Processing Record 39 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 8 | lagoa
# Processing Record 41 of Set 8 | serrinha
# Processing Record 42 of Set 8 | taltal
# Processing Record 43 of Set 8 | waverly
# Processing Record 44 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 8 | padang
# Processing Record 46 of Set 8 | lida
# Processing Record 47 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 8 | tikrit
# Processing Record 49 of Set 8 | hirara
# Processing Record 50 of Set 8 | odesskoye
# Processing Record 1 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 9 | nouadhibou
# Processing Record 3 of Set 9 | gravdal
# Processing Record 4 of Set 9 | hvolsvollur
# Processing Record 5 of Set 9 | inongo
# Processing Record 6 of Set 9 | mancio lima
# Processing Record 7 of Set 9 | kalulushi
# Processing Record 8 of Set 9 | cavalcante
# Processing Record 9 of Set 9 | pisco
# Processing Record 10 of Set 9 | suratgarh
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 13 of Set 9 | iralaya
# Processing Record 14 of Set 9 | conselheiro pena
# Processing Record 15 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 9 | gazanjyk
# Processing Record 17 of Set 9 | domoni
# Processing Record 18 of Set 9 | savannah bight
# Processing Record 19 of Set 9 | yar-sale
# Processing Record 20 of Set 9 | bati
# Processing Record 21 of Set 9 | plettenberg bay
# Processing Record 22 of Set 9 | awjilah
# Processing Record 23 of Set 9 | comodoro rivadavia
# Processing Record 24 of Set 9 | rathcoole
# Processing Record 25 of Set 9 | constantine
# Processing Record 26 of Set 9 | tautira
# Processing Record 27 of Set 9 | wanning
# Processing Record 28 of Set 9 | san cristobal
# Processing Record 29 of Set 9 | buala
# Processing Record 30 of Set 9 | mecca
# Processing Record 31 of Set 9 | oranjemund
# Processing Record 32 of Set 9 | zhuhai
# Processing Record 33 of Set 9 | odweyne
# Processing Record 34 of Set 9 | ajdabiya
# Processing Record 35 of Set 9 | tchaourou
# Processing Record 36 of Set 9 | pavlovskiy posad
# Processing Record 37 of Set 9 | porbandar
# Processing Record 38 of Set 9 | puerto escondido
# Processing Record 39 of Set 9 | kastamonu
# Processing Record 40 of Set 9 | praia da vitoria
# Processing Record 41 of Set 9 | chifeng
# Processing Record 42 of Set 9 | butembo
# Processing Record 43 of Set 9 | verkhneuralsk
# Processing Record 44 of Set 9 | jaisalmer
# Processing Record 45 of Set 9 | yulara
# Processing Record 46 of Set 9 | horsham
# Processing Record 47 of Set 9 | beboto
# Processing Record 48 of Set 9 | pirogovo
# Processing Record 49 of Set 9 | fukue
# Processing Record 50 of Set 9 | yamada
# Processing Record 1 of Set 10 | lorengau
# Processing Record 2 of Set 10 | kruisfontein
# Processing Record 3 of Set 10 | okitipupa
# Processing Record 4 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 10 | borsa
# Processing Record 6 of Set 10 | birjand
# Processing Record 7 of Set 10 | waipawa
# Processing Record 8 of Set 10 | dawei
# Processing Record 9 of Set 10 | crestview
# Processing Record 10 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 10 | erzin
# Processing Record 12 of Set 10 | tomatlan
# Processing Record 13 of Set 10 | port macquarie
# Processing Record 14 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 10 | san borja
# Processing Record 16 of Set 10 | dudinka
# Processing Record 17 of Set 10 | makokou
# Processing Record 18 of Set 10 | milkovo
# Processing Record 19 of Set 10 | tessalit
# Processing Record 20 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 10 | baykit
# Processing Record 22 of Set 10 | belaya rechka
# Processing Record 23 of Set 10 | dospat
# Processing Record 24 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 10 | zhongshu
# Processing Record 26 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 10 | axim
# Processing Record 28 of Set 10 | salym
# Processing Record 29 of Set 10 | galveston
# Processing Record 30 of Set 10 | hualmay
# Processing Record 31 of Set 10 | mahanje
# Processing Record 32 of Set 10 | nazret
# Processing Record 33 of Set 10 | zatoka
# Processing Record 34 of Set 10 | sainte-maxime
# Processing Record 35 of Set 10 | bonthe
# Processing Record 36 of Set 10 | kyaikkami
# Processing Record 37 of Set 10 | hamilton
# Processing Record 38 of Set 10 | bad freienwalde
# Processing Record 39 of Set 10 | penzance
# Processing Record 40 of Set 10 | esmeraldas
# Processing Record 41 of Set 10 | pelym
# Processing Record 42 of Set 10 | kalundborg
# Processing Record 43 of Set 10 | vostok
# Processing Record 44 of Set 10 | maneromango
# Processing Record 45 of Set 10 | kanigiri
# Processing Record 46 of Set 10 | sharan
# Processing Record 47 of Set 10 | yambio
# Processing Record 48 of Set 10 | villa bruzual
# Processing Record 49 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 10 | novyy yegorlyk
# Processing Record 1 of Set 11 | say
# Processing Record 2 of Set 11 | beira
# Processing Record 3 of Set 11 | sibut
# Processing Record 4 of Set 11 | sile
# Processing Record 5 of Set 11 | quibdo
# Processing Record 6 of Set 11 | ixtapa
# Processing Record 7 of Set 11 | mangai
# Processing Record 8 of Set 11 | paso de los toros
# Processing Record 9 of Set 11 | pemberton
# Processing Record 10 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | mwene-ditu
# Processing Record 12 of Set 11 | kieta
# Processing Record 13 of Set 11 | teguldet
# Processing Record 14 of Set 11 | pontianak
# Processing Record 15 of Set 11 | ruwi
# Processing Record 16 of Set 11 | pingliang
# Processing Record 17 of Set 11 | rafaela
# Processing Record 18 of Set 11 | alice springs
# Processing Record 19 of Set 11 | haines junction
# Processing Record 20 of Set 11 | obo
# Processing Record 21 of Set 11 | umm lajj
# Processing Record 22 of Set 11 | alpena
# Processing Record 23 of Set 11 | nushki
# Processing Record 24 of Set 11 | cabo san lucas
# Processing Record 25 of Set 11 | morondava
# Processing Record 26 of Set 11 | thai binh
# Processing Record 27 of Set 11 | ponta do sol
# Processing Record 28 of Set 11 | deloraine
# Processing Record 29 of Set 11 | wajir
# Processing Record 30 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 11 | plouzane
# Processing Record 32 of Set 11 | yurga
# Processing Record 33 of Set 11 | tiznit
# Processing Record 34 of Set 11 | kasongo-lunda
# Processing Record 35 of Set 11 | siteki
# Processing Record 36 of Set 11 | nara
# Processing Record 37 of Set 11 | broome
# Processing Record 38 of Set 11 | hay river
# Processing Record 39 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 40 of Set 11 | araripina
# Processing Record 41 of Set 11 | vermilion
# Processing Record 42 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 11 | sinnamary
# Processing Record 44 of Set 11 | hendersonville
# Processing Record 45 of Set 11 | araouane
# Processing Record 46 of Set 11 | norman wells
# Processing Record 47 of Set 11 | tyukhtet
# Processing Record 48 of Set 11 | inhambane
# Processing Record 49 of Set 11 | bull savanna
# Processing Record 50 of Set 11 | tazmalt
# Processing Record 1 of Set 12 | hambantota
# Processing Record 2 of Set 12 | tual
# Processing Record 3 of Set 12 | sarangani
# Processing Record 4 of Set 12 | khed
# Processing Record 5 of Set 12 | oranjestad
# Processing Record 6 of Set 12 | beyneu
# Processing Record 7 of Set 12 | sibu
# Processing Record 8 of Set 12 | reconquista
# Processing Record 9 of Set 12 | goiatuba
# Processing Record 10 of Set 12 | yumen
# Processing Record 11 of Set 12 | grand gaube
# Processing Record 12 of Set 12 | shiyan
# Processing Record 13 of Set 12 | ailigandi
# Processing Record 14 of Set 12 | itarema
# Processing Record 15 of Set 12 | san vicente
# Processing Record 16 of Set 12 | victor harbor
# Processing Record 17 of Set 12 | lucapa
# Processing Record 18 of Set 12 | salta
# Processing Record 19 of Set 12 | kurayoshi
# Processing Record 20 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 12 | sitka
# Processing Record 22 of Set 12 | wormeldange
# Processing Record 23 of Set 12 | concord
# Processing Record 24 of Set 12 | hayden
# Processing Record 25 of Set 12 | calbuco
# Processing Record 26 of Set 12 | novouzensk
# Processing Record 27 of Set 12 | qadian
# Processing Record 28 of Set 12 | gusau
# Processing Record 29 of Set 12 | sokolo
# Processing Record 30 of Set 12 | bairiki
# Processing Record 31 of Set 12 | jalingo
# Processing Record 32 of Set 12 | kuala krai
# City not found. Skipping...
# Processing Record 33 of Set 12 | cabrero
# Processing Record 34 of Set 12 | seoul
# Processing Record 35 of Set 12 | muborak
# Processing Record 36 of Set 12 | orange
# Processing Record 37 of Set 12 | paternion
# Processing Record 38 of Set 12 | marigot
# Processing Record 39 of Set 12 | vanimo
# Processing Record 40 of Set 12 | celestun
# Processing Record 41 of Set 12 | bilma
# Processing Record 42 of Set 12 | dubbo
# Processing Record 43 of Set 12 | hays
# Processing Record 44 of Set 12 | yarensk
# Processing Record 45 of Set 12 | esfarayen
# Processing Record 46 of Set 12 | dunedin
# Processing Record 47 of Set 12 | puerto baquerizo moreno
# Processing Record 48 of Set 12 | ulladulla
# Processing Record 49 of Set 12 | kahului
# Processing Record 50 of Set 12 | bundaberg
# Processing Record 1 of Set 13 | carora
# Processing Record 2 of Set 13 | kinshasa
# Processing Record 3 of Set 13 | clarence town
# Processing Record 4 of Set 13 | puerto maldonado
# Processing Record 5 of Set 13 | wahiawa
# Processing Record 6 of Set 13 | ilave
# Processing Record 7 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 13 | ahar
# Processing Record 9 of Set 13 | kysyl-syr
# Processing Record 10 of Set 13 | uramita
# Processing Record 11 of Set 13 | maarianhamina
# Processing Record 12 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 13 of Set 13 | lovozero
# Processing Record 14 of Set 13 | general pico
# Processing Record 15 of Set 13 | mabaruma
# Processing Record 16 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 13 | boca do acre
# Processing Record 18 of Set 13 | kloulklubed
# Processing Record 19 of Set 13 | mount pleasant
# Processing Record 20 of Set 13 | santiago del estero
# Processing Record 21 of Set 13 | jiaxing
# Processing Record 22 of Set 13 | tarko-sale
# Processing Record 23 of Set 13 | porto novo
# Processing Record 24 of Set 13 | koulikoro
# Processing Record 25 of Set 13 | teya
# Processing Record 26 of Set 13 | nabire
# Processing Record 27 of Set 13 | abu samrah
# Processing Record 28 of Set 13 | barcelos
# Processing Record 29 of Set 13 | rosario
# Processing Record 30 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 31 of Set 13 | den chai
# Processing Record 32 of Set 13 | mahon
# Processing Record 33 of Set 13 | mingshui
# Processing Record 34 of Set 13 | maragogi
# Processing Record 35 of Set 13 | qasigiannguit
# Processing Record 36 of Set 13 | aykhal
# Processing Record 37 of Set 13 | yerbogachen
# Processing Record 38 of Set 13 | salinopolis
# Processing Record 39 of Set 13 | matara
# Processing Record 40 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 13 | khandyga
# Processing Record 42 of Set 13 | melfi
# Processing Record 43 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 13 | shelburne
# Processing Record 45 of Set 13 | vakhtan
# Processing Record 46 of Set 13 | tyukalinsk
# Processing Record 47 of Set 13 | churapcha
# Processing Record 48 of Set 13 | zhanaozen
# Processing Record 49 of Set 13 | elizabeth city
# Processing Record 50 of Set 13 | garissa
# Processing Record 1 of Set 14 | poya
# Processing Record 2 of Set 14 | nagua
# Processing Record 3 of Set 14 | athmallik
# Processing Record 4 of Set 14 | narsaq
# Processing Record 5 of Set 14 | la asuncion
# Processing Record 6 of Set 14 | jiazi
# Processing Record 7 of Set 14 | zaraza
# Processing Record 8 of Set 14 | kalcheva
# Processing Record 9 of Set 14 | sept-iles
# Processing Record 10 of Set 14 | puerto penasco
# Processing Record 11 of Set 14 | balud
# Processing Record 12 of Set 14 | avera
# Processing Record 13 of Set 14 | amancio
# City not found. Skipping...
# Processing Record 14 of Set 14 | ocos
# Processing Record 15 of Set 14 | kichera
# Processing Record 16 of Set 14 | sandpoint
# Processing Record 17 of Set 14 | sao francisco
# Processing Record 18 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 14 | ca mau
# Processing Record 20 of Set 14 | agirish
# Processing Record 21 of Set 14 | wad madani
# Processing Record 22 of Set 14 | chabahar
# Processing Record 23 of Set 14 | oriximina
# Processing Record 24 of Set 14 | calvinia
# Processing Record 25 of Set 14 | benjamin constant
# Processing Record 26 of Set 14 | sengiley
# Processing Record 27 of Set 14 | dickinson
# Processing Record 28 of Set 14 | impfondo
# Processing Record 29 of Set 14 | port hedland
# Processing Record 30 of Set 14 | otorohanga
# Processing Record 31 of Set 14 | ahuimanu
# Processing Record 32 of Set 14 | aktas
# Processing Record 33 of Set 14 | alihe
# Processing Record 34 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 14 | adrar
# Processing Record 36 of Set 14 | vila
# Processing Record 37 of Set 14 | ayan
# Processing Record 38 of Set 14 | kambove
# Processing Record 39 of Set 14 | laguna
# Processing Record 40 of Set 14 | graaff-reinet
# Processing Record 41 of Set 14 | bowen
# Processing Record 42 of Set 14 | kontagora
# Processing Record 43 of Set 14 | buena vista
# Processing Record 44 of Set 14 | shenjiamen
# Processing Record 45 of Set 14 | lasa
# Processing Record 46 of Set 14 | aleksandrov gay
# Processing Record 47 of Set 14 | saint-denis
# Processing Record 48 of Set 14 | auki
# Processing Record 49 of Set 14 | castelo do piaui
# Processing Record 50 of Set 14 | rapid valley
# Processing Record 1 of Set 15 | bouna
# Processing Record 2 of Set 15 | aloleng
# Processing Record 3 of Set 15 | schoneiche
# Processing Record 4 of Set 15 | ucluelet
# Processing Record 5 of Set 15 | westport
# Processing Record 6 of Set 15 | sioux lookout
# Processing Record 7 of Set 15 | changji
# Processing Record 8 of Set 15 | ipixuna
# Processing Record 9 of Set 15 | kolpashevo
# Processing Record 10 of Set 15 | zhicheng
# Processing Record 11 of Set 15 | roald
# Processing Record 12 of Set 15 | flin flon
# Processing Record 13 of Set 15 | wawa
# Processing Record 14 of Set 15 | venancio aires
# Processing Record 15 of Set 15 | zhaotong
# Processing Record 16 of Set 15 | natal
# Processing Record 17 of Set 15 | novoagansk
# Processing Record 18 of Set 15 | muros
# Processing Record 19 of Set 15 | mikhaylovka
# Processing Record 20 of Set 15 | canutama
# Processing Record 21 of Set 15 | karratha
# Processing Record 22 of Set 15 | lydenburg
# Processing Record 23 of Set 15 | iberia
# Processing Record 24 of Set 15 | mackenzie
# Processing Record 25 of Set 15 | higuey
# City not found. Skipping...
# Processing Record 26 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 15 | port augusta
# Processing Record 28 of Set 15 | yantal
# Processing Record 29 of Set 15 | gao
# Processing Record 30 of Set 15 | coos bay
# Processing Record 31 of Set 15 | bhadasar
# Processing Record 32 of Set 15 | hovd
# Processing Record 33 of Set 15 | kosh-agach
# Processing Record 34 of Set 15 | melilla
# Processing Record 35 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 15 | katobu
# Processing Record 37 of Set 15 | kendari
# Processing Record 38 of Set 15 | honiton
# Processing Record 39 of Set 15 | akropong
# Processing Record 40 of Set 15 | formosa do rio preto
# Processing Record 41 of Set 15 | betare oya
# Processing Record 42 of Set 15 | chipinge
# Processing Record 43 of Set 15 | bagdarin
# Processing Record 44 of Set 15 | aguascalientes
# Processing Record 45 of Set 15 | timberlake
# Processing Record 46 of Set 15 | dharchula
# Processing Record 47 of Set 15 | sao jose da coroa grande
# Processing Record 48 of Set 15 | yingcheng
# Processing Record 49 of Set 15 | pringsewu
# Processing Record 50 of Set 15 | henderson
# Processing Record 1 of Set 16 | talnakh
# Processing Record 2 of Set 16 | tunxi
# City not found. Skipping...
# Processing Record 3 of Set 16 | tigil
# Processing Record 4 of Set 16 | redmond
# Processing Record 5 of Set 16 | kabare
# Processing Record 6 of Set 16 | agadez
# Processing Record 7 of Set 16 | yauya
# Processing Record 8 of Set 16 | kleck
# City not found. Skipping...
# Processing Record 9 of Set 16 | cayenne
# Processing Record 10 of Set 16 | saint anthony
# Processing Record 11 of Set 16 | pilao arcado
# City not found. Skipping...
# Processing Record 12 of Set 16 | vieux-habitants
# Processing Record 13 of Set 16 | lilongwe
# Processing Record 14 of Set 16 | lethem
# Processing Record 15 of Set 16 | luanda
# Processing Record 16 of Set 16 | ha giang
# Processing Record 17 of Set 16 | rezekne
# Processing Record 18 of Set 16 | lebedyn
# Processing Record 19 of Set 16 | adamovka
# Processing Record 20 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 16 | dutlwe
# Processing Record 22 of Set 16 | kem
# Processing Record 23 of Set 16 | batemans bay
# Processing Record 24 of Set 16 | palauig
# Processing Record 25 of Set 16 | huilong
# Processing Record 26 of Set 16 | te anau
# Processing Record 27 of Set 16 | beni suef
# Processing Record 28 of Set 16 | deyang
# Processing Record 29 of Set 16 | vincennes
# Processing Record 30 of Set 16 | rawson
# Processing Record 31 of Set 16 | sobolevo
# Processing Record 32 of Set 16 | oneonta
# Processing Record 33 of Set 16 | alta floresta
# Processing Record 34 of Set 16 | nancha
# Processing Record 35 of Set 16 | boa vista
# Processing Record 36 of Set 16 | elko
# Processing Record 37 of Set 16 | linxia
# Processing Record 38 of Set 16 | taunggyi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 724

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                        City      Lat       Lng  Max Temp  Min Temp  Humidity  \
# 0           Lazaro Cardenas  17.9583 -102.2000     72.07     72.07        84
# 1  Sao Gabriel Da Cachoeira  -0.1303  -67.0892     74.10     74.10        91
# 2                   Ushuaia -54.8000  -68.3000     39.88     39.88        83
# 3                   Rikitea -23.1203 -134.9692     76.41     76.41        81
# 4             Venado Tuerto -33.7456  -61.9688     59.25     59.25        70
# 5                     Asyut  27.1810   31.1837     62.10     62.10        36
# 6                    Bethel  41.3712  -73.4140     35.96     31.06        84
# 7                     Bluff -46.6000  168.3333     50.81     50.81        73
# 8                    Dikson  73.5069   80.5464    -19.28    -19.28       100
# 9            Saint-Francois  46.4154    3.9054     55.65     54.68        89
#
#    Cloudiness  Wind Speed Current Description Country                 Date
# 0           0        4.52           clear sky      MX  2024-01-24 10:10:20
# 1          52        0.29       broken clouds      BR  2024-01-24 10:10:20
# 2          55        3.36       broken clouds      AR  2024-01-24 10:10:20
# 3         100       12.30     overcast clouds      PF  2024-01-24 10:10:20
# 4           0        8.34           clear sky      AR  2024-01-24 10:10:20
# 5          30       13.04    scattered clouds      EG  2024-01-24 10:08:46
# 6         100        1.99     overcast clouds      US  2024-01-24 10:10:20
# 7          63        7.47       broken clouds      NZ  2024-01-24 10:10:20
# 8           5        8.01           clear sky      RU  2024-01-24 10:10:20
# 9          75        8.05       broken clouds      FR  2024-01-24 10:10:20

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Min Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Min Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                        City Country                 Date      Lat       Lng  \
# 0           Lazaro Cardenas      MX  2024-01-24 10:10:20  17.9583 -102.2000
# 1  Sao Gabriel Da Cachoeira      BR  2024-01-24 10:10:20  -0.1303  -67.0892
# 2                   Ushuaia      AR  2024-01-24 10:10:20 -54.8000  -68.3000
# 3                   Rikitea      PF  2024-01-24 10:10:20 -23.1203 -134.9692
# 4             Venado Tuerto      AR  2024-01-24 10:10:20 -33.7456  -61.9688
# 5                     Asyut      EG  2024-01-24 10:08:46  27.1810   31.1837
# 6                    Bethel      US  2024-01-24 10:10:20  41.3712  -73.4140
# 7                     Bluff      NZ  2024-01-24 10:10:20 -46.6000  168.3333
# 8                    Dikson      RU  2024-01-24 10:10:20  73.5069   80.5464
# 9            Saint-Francois      FR  2024-01-24 10:10:20  46.4154    3.9054
#
#    Max Temp  Min Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     72.07     72.07        84           0        4.52           clear sky
# 1     74.10     74.10        91          52        0.29       broken clouds
# 2     39.88     39.88        83          55        3.36       broken clouds
# 3     76.41     76.41        81         100       12.30     overcast clouds
# 4     59.25     59.25        70           0        8.34           clear sky
# 5     62.10     62.10        36          30       13.04    scattered clouds
# 6     35.96     31.06        84         100        1.99     overcast clouds
# 7     50.81     50.81        73          63        7.47       broken clouds
# 8    -19.28    -19.28       100           5        8.01           clear sky
# 9     55.65     54.68        89          75        8.05       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Min Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "//Users/miracleonyeoziri/Documents/Bootcamp Materials/Module 6/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
