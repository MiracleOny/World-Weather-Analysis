# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("/Users/miracleonyeoziri/Documents/Bootcamp Materials/Module 6/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv")

# Display sample data
city_data_df.head(10)
# Out:
#    City_ID                      City Country                 Date      Lat  \
# 0        0           Lazaro Cardenas      MX  2024-01-24 10:10:20  17.9583
# 1        1  Sao Gabriel Da Cachoeira      BR  2024-01-24 10:10:20  -0.1303
# 2        2                   Ushuaia      AR  2024-01-24 10:10:20 -54.8000
# 3        3                   Rikitea      PF  2024-01-24 10:10:20 -23.1203
# 4        4             Venado Tuerto      AR  2024-01-24 10:10:20 -33.7456
# 5        5                     Asyut      EG  2024-01-24 10:08:46  27.1810
# 6        6                    Bethel      US  2024-01-24 10:10:20  41.3712
# 7        7                     Bluff      NZ  2024-01-24 10:10:20 -46.6000
# 8        8                    Dikson      RU  2024-01-24 10:10:20  73.5069
# 9        9            Saint-Francois      FR  2024-01-24 10:10:20  46.4154
#
#         Lng  Max Temp  Min Temp  Humidity  Cloudiness  Wind Speed  \
# 0 -102.2000     72.07     72.07        84           0        4.52
# 1  -67.0892     74.10     74.10        91          52        0.29
# 2  -68.3000     39.88     39.88        83          55        3.36
# 3 -134.9692     76.41     76.41        81         100       12.30
# 4  -61.9688     59.25     59.25        70           0        8.34
# 5   31.1837     62.10     62.10        36          30       13.04
# 6  -73.4140     35.96     31.06        84         100        1.99
# 7  168.3333     50.81     50.81        73          63        7.47
# 8   80.5464    -19.28    -19.28       100           5        8.01
# 9    3.9054     55.65     54.68        89          75        8.05
#
#   Current Description
# 0           clear sky
# 1       broken clouds
# 2       broken clouds
# 3     overcast clouds
# 4           clear sky
# 5    scattered clouds
# 6     overcast clouds
# 7       broken clouds
# 8           clear sky
# 9       broken clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria. # \n ---> newline  ---> It causes a line break
ideal_min_temp = float(input("What is the minimum temperature you would like for your vacation? "))
ideal_max_temp = float(input("What is the maximum temperature you would like for your vacation? "))
print(ideal_min_temp, ideal_max_temp) #70 & 90 degress
# Out:
# 70.0 90.0

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] < ideal_max_temp) & (city_data_df["Min Temp"] > ideal_min_temp)]

# Display sample data
display(preferred_cities_df)
# Out:
#      City_ID                      City Country                 Date      Lat  \
# 0          0           Lazaro Cardenas      MX  2024-01-24 10:10:20  17.9583
# 1          1  Sao Gabriel Da Cachoeira      BR  2024-01-24 10:10:20  -0.1303
# 3          3                   Rikitea      PF  2024-01-24 10:10:20 -23.1203
# 18        18                 Katherine      AU  2024-01-24 10:10:21 -14.4667
# 20        20                       Vao      NC  2024-01-24 10:10:21 -22.6667
# ..       ...                       ...     ...                  ...      ...
# 708      708              Batemans Bay      AU  2024-01-24 11:04:40 -35.7167
# 709      709                   Palauig      PH  2024-01-24 11:04:41  15.4350
# 715      715                    Rawson      AR  2024-01-24 11:04:41 -43.3002
# 718      718             Alta Floresta      BR  2024-01-24 11:04:42  -9.8756
# 720      720                 Boa Vista      BR  2024-01-24 11:04:42   2.8197
#
#           Lng  Max Temp  Min Temp  Humidity  Cloudiness  Wind Speed  \
# 0   -102.2000     72.07     72.07        84           0        4.52
# 1    -67.0892     74.10     74.10        91          52        0.29
# 3   -134.9692     76.41     76.41        81         100       12.30
# 18   132.2667     79.12     79.12       100         100        4.61
# 20   167.4833     78.49     78.49        75         100        8.39
# ..        ...       ...       ...       ...         ...         ...
# 708  150.1833     74.50     74.50        64          32        4.16
# 709  119.9045     78.57     78.57        74          73        6.22
# 715  -65.1023     73.94     73.94        39          33       11.65
# 718  -56.0861     73.02     73.02        99         100        2.08
# 720  -60.6733     76.98     76.98        69           0       17.27
#
#     Current Description
# 0             clear sky
# 1         broken clouds
# 3       overcast clouds
# 18      overcast clouds
# 20      overcast clouds
# ..                  ...
# 708    scattered clouds
# 709       broken clouds
# 715    scattered clouds
# 718     overcast clouds
# 720           clear sky
#
# [274 rows x 12 columns]

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# How many NaN are in the dataframe
preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                5
# Date                   0
# Lat                    0
# Lng                    0
# Max Temp               0
# Min Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                0
# Date                   0
# Lat                    0
# Lng                    0
# Max Temp               0
# Min Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# Display sample data
display(clean_travel_cities)
# Out:
#      City_ID                      City Country                 Date      Lat  \
# 0          0           Lazaro Cardenas      MX  2024-01-24 10:10:20  17.9583
# 1          1  Sao Gabriel Da Cachoeira      BR  2024-01-24 10:10:20  -0.1303
# 3          3                   Rikitea      PF  2024-01-24 10:10:20 -23.1203
# 18        18                 Katherine      AU  2024-01-24 10:10:21 -14.4667
# 20        20                       Vao      NC  2024-01-24 10:10:21 -22.6667
# ..       ...                       ...     ...                  ...      ...
# 708      708              Batemans Bay      AU  2024-01-24 11:04:40 -35.7167
# 709      709                   Palauig      PH  2024-01-24 11:04:41  15.4350
# 715      715                    Rawson      AR  2024-01-24 11:04:41 -43.3002
# 718      718             Alta Floresta      BR  2024-01-24 11:04:42  -9.8756
# 720      720                 Boa Vista      BR  2024-01-24 11:04:42   2.8197
#
#           Lng  Max Temp  Min Temp  Humidity  Cloudiness  Wind Speed  \
# 0   -102.2000     72.07     72.07        84           0        4.52
# 1    -67.0892     74.10     74.10        91          52        0.29
# 3   -134.9692     76.41     76.41        81         100       12.30
# 18   132.2667     79.12     79.12       100         100        4.61
# 20   167.4833     78.49     78.49        75         100        8.39
# ..        ...       ...       ...       ...         ...         ...
# 708  150.1833     74.50     74.50        64          32        4.16
# 709  119.9045     78.57     78.57        74          73        6.22
# 715  -65.1023     73.94     73.94        39          33       11.65
# 718  -56.0861     73.02     73.02        99         100        2.08
# 720  -60.6733     76.98     76.98        69           0       17.27
#
#     Current Description
# 0             clear sky
# 1         broken clouds
# 3       overcast clouds
# 18      overcast clouds
# 20      overcast clouds
# ..                  ...
# 708    scattered clouds
# 709       broken clouds
# 715    scattered clouds
# 718     overcast clouds
# 720           clear sky
#
# [269 rows x 12 columns]

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head(10)
# Out:
#                         City Country  Max Temp Current Description      Lat  \
# 0            Lazaro Cardenas      MX     72.07           clear sky  17.9583
# 1   Sao Gabriel Da Cachoeira      BR     74.10       broken clouds  -0.1303
# 3                    Rikitea      PF     76.41     overcast clouds -23.1203
# 18                 Katherine      AU     79.12     overcast clouds -14.4667
# 20                       Vao      NC     78.49     overcast clouds -22.6667
# 24                 Carnarvon      AU     76.05    scattered clouds -24.8667
# 26                     Alofi      NU     79.92     overcast clouds -19.0595
# 27                    Touros      BR     82.83    scattered clouds  -5.1989
# 28                      Yako      BF     85.62           clear sky  12.9667
# 29                    Dingle      PH     77.85          few clouds  10.9995
#
#          Lng Hotel Name
# 0  -102.2000
# 1   -67.0892
# 3  -134.9692
# 18  132.2667
# 20  167.4833
# 24  113.6333
# 26 -169.9187
# 27  -35.4608
# 28   -2.2667
# 29  122.6711

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Lazaro Cardenas - nearest hotel: Hotel Sol del Pacífico
# Sao Gabriel Da Cachoeira - nearest hotel: Hotel Deus Me Deu
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Katherine - nearest hotel: No hotel found
# Vao - nearest hotel: Nataiwatch
# Carnarvon - nearest hotel: No hotel found
# Alofi - nearest hotel: No hotel found
# Touros - nearest hotel: Pousada Atlântico
# Yako - nearest hotel: No hotel found
# Dingle - nearest hotel: No hotel found
# Cidreira - nearest hotel: Hotel Castelo
# Tari - nearest hotel: No hotel found
# Hithadhoo - nearest hotel: Pebbles Inn
# Pangkalanbuun - nearest hotel: Hotel Tiara
# Sao Felix Do Xingu - nearest hotel: Hotel Terraço
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Busselton - nearest hotel: Ithaca
# Bengkulu - nearest hotel: Dena Hotel
# Tamandare - nearest hotel: Pousada Baia dos Corais
# Japura - nearest hotel: No hotel found
# Avarua - nearest hotel: Paradise Inn
# Salalah - nearest hotel: Muscat International Hotel
# Trairi - nearest hotel: No hotel found
# Coahuayana - nearest hotel: No hotel found
# Hermanus - nearest hotel: Aloe guest house
# Sulangan - nearest hotel: Marion's Inn
# Acajutla - nearest hotel: Hotel Lara
# Bredasdorp - nearest hotel: Victoria Hotel
# Port Elizabeth - nearest hotel: Waterford Hotel
# Cockburn Town - nearest hotel: The Salt Raker Inn
# Omboue - nearest hotel: Hôtel Georges Faustin Aurat
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Mackay - nearest hotel: Mackay Oceanside Central Apartment Hotel
# Quatre Cocos - nearest hotel: Horisun
# East London - nearest hotel: No hotel found
# Vaini - nearest hotel: Keleti International Resort
# Kirakira - nearest hotel: No hotel found
# Richards Bay - nearest hotel: SUN1 Richards Bay
# Butaritari - nearest hotel: No hotel found
# Najran - nearest hotel: No hotel found
# Port Alfred - nearest hotel: No hotel found
# Atuona - nearest hotel: Pearl Resort
# Bambous Virieux - nearest hotel: No hotel found
# Pemba - nearest hotel: Hotel Rafael
# Antsohihy - nearest hotel: Escale
# Kavaratti - nearest hotel: No hotel found
# Livramento - nearest hotel: No hotel found
# Kamwenge - nearest hotel: Club Africa Hotel Ltd
# Sabang - nearest hotel: Sabang Hill
# Labuhan - nearest hotel: No hotel found
# Bolitoc - nearest hotel: Coco beach resort
# Georgetown - nearest hotel: Page 63 hostel
# Cabedelo - nearest hotel: No hotel found
# Doha - nearest hotel: Al MIrqab
# Saint-Philippe - nearest hotel: Le Baril
# Mahebourg - nearest hotel: Grand Bel Air
# Varjota - nearest hotel: Imediato
# Sorong - nearest hotel: Hotel Membramo Marina
# Nhulunbuy - nearest hotel: No hotel found
# Morant Bay - nearest hotel: Morant Villas
# Road Town - nearest hotel: No hotel found
# Vieques - nearest hotel: The St. Regis Bahia Beach Resort, Puerto Rico
# Kapaa - nearest hotel: Pono Kai Resort
# Vila Velha - nearest hotel: Hotel Prainha
# Nam Som - nearest hotel: No hotel found
# Banyo - nearest hotel: Hôtel Amin
# Soyo - nearest hotel: Hotel Maria Teres
# Nizwa - nearest hotel: Nizwa Heritage Inn
# Honiara - nearest hotel: King Solomon Hotel
# Riyadh - nearest hotel: White Palace Hotel
# Sur - nearest hotel: Sur Hotel
# Gurupa - nearest hotel: No hotel found
# Peyima - nearest hotel: No hotel found
# Tutoia - nearest hotel: Pousada San Vicente
# Biak - nearest hotel: No hotel found
# Morros - nearest hotel: No hotel found
# Maceio - nearest hotel: Maceió Hostel e Pousada
# Faanui - nearest hotel: Oa Oa Lodge
# Yeppoon - nearest hotel: Blossom's on Seaspray
# Polewali - nearest hotel: hotel perdana
# Brownsville - nearest hotel: Cameron Hotel
# Bari Sadri - nearest hotel: No hotel found
# Daru - nearest hotel: Kuki
# Souillac - nearest hotel: Hotel SkylineInn
# Sao Filipe - nearest hotel: Bela Vista
# Pombas - nearest hotel: Aldeia Jerome
# Sambava - nearest hotel: Royal Sava Hôtel
# Alyangula - nearest hotel: Pole 13 Camp
# Atambua - nearest hotel: Hotel Matahari
# Harper - nearest hotel: No hotel found
# Meulaboh - nearest hotel: Hotel Meuligou
# Bosaso - nearest hotel: Bosaso hotel
# Port-Gentil - nearest hotel: Tara-Mé
# Sola - nearest hotel: No hotel found
# Saldanha - nearest hotel: Hoedjesbaai
# Casambalangan - nearest hotel: No hotel found
# Moroni - nearest hotel: Ville de Moroni
# Cap Malheureux - nearest hotel: Cape Garden
# Kanniyakumari - nearest hotel: The Seashore Hotel
# Kharhial - nearest hotel: No hotel found
# Hobyo - nearest hotel: Iftin Hotel Hobyo
# Quelimane - nearest hotel: Mabassa
# Kupang - nearest hotel: HOTEL SALUNGA
# Arlit - nearest hotel: No hotel found
# Gigmoto - nearest hotel: No hotel found
# Geraldton - nearest hotel: Ocean Centre Hotel
# Sa Kaeo - nearest hotel: No hotel found
# Dakar - nearest hotel: 翁记小吃
# Talen - nearest hotel: No hotel found
# Vangaindrano - nearest hotel: Fanilo
# Flinders - nearest hotel: No hotel found
# Placido De Castro - nearest hotel: No hotel found
# Samarai - nearest hotel: No hotel found
# Bathsheba - nearest hotel: Atlantis Hotel
# Zumarraga - nearest hotel: No hotel found
# Caravelas - nearest hotel: Pousada dos Navegantes
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Namatanai - nearest hotel: Namatanai Hotel
# Eydhafushi - nearest hotel: No hotel found
# Bitung - nearest hotel: Favehotel Bitung - North Sulawesi
# Pitimbu - nearest hotel: Pousada Brisa Mar
# Alvaraes - nearest hotel: Hotel Divino
# Kununurra - nearest hotel: No hotel found
# Olinda - nearest hotel: Fidji Motel
# Bombay - nearest hotel: Hotel City Point
# Mana - nearest hotel: Le Samana
# Cururupu - nearest hotel: No hotel found
# Kavieng - nearest hotel: Kavieng Hotel
# Beloha - nearest hotel: Hôtel Oliv
# Isangel - nearest hotel: Tanna Lodge
# Saint-Pierre - nearest hotel: Tropic Hotel
# Mafinga - nearest hotel: No hotel found
# Zambezi - nearest hotel: No hotel found
# Bukama - nearest hotel: Mission catholique
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Serrinha - nearest hotel: No hotel found
# Padang - nearest hotel: losmen Surya
# Inongo - nearest hotel: Chez LELE IYOLO
# Mancio Lima - nearest hotel: No hotel found
# Kalulushi - nearest hotel: No hotel found
# Cavalcante - nearest hotel: Pousada Chalés do Lago
# Pisco - nearest hotel: La Portada
# Bandarbeyla - nearest hotel: No hotel found
# Iralaya - nearest hotel: No hotel found
# Conselheiro Pena - nearest hotel: No hotel found
# Domoni - nearest hotel: Hotel Djadid
# Savannah Bight - nearest hotel: La Giralda
# Bati - nearest hotel: No hotel found
# Plettenberg Bay - nearest hotel: Milkwood Manor
# Tautira - nearest hotel: No hotel found
# Buala - nearest hotel: No hotel found
# Mecca - nearest hotel: Rehab Al Marwa Hotel 1
# Odweyne - nearest hotel: فندق المدينه
# Tchaourou - nearest hotel: Auberge
# Porbandar - nearest hotel: Toran Tourist Bungalow
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Butembo - nearest hotel: Canada House
# Jaisalmer - nearest hotel: Jeet Mahal
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Kruisfontein - nearest hotel: No hotel found
# Dawei - nearest hotel: Royal Dawei ဟိုတယ်
# San Borja - nearest hotel: No hotel found
# Tessalit - nearest hotel: No hotel found
# Axim - nearest hotel: Axim Beach Hotel
# Hualmay - nearest hotel: Hotel Mi Choacan
# Mahanje - nearest hotel: No hotel found
# Nazret - nearest hotel: ኤግል ሆቴል
# Bonthe - nearest hotel: No hotel found
# Kyaikkami - nearest hotel: ရှုခင်းသာ
# Maneromango - nearest hotel: No hotel found
# Kanigiri - nearest hotel: No hotel found
# Villa Bruzual - nearest hotel: Hotel Turístico Sol de Arichuna
# Say - nearest hotel: No hotel found
# Beira - nearest hotel: Hotel Savoy
# Quibdo - nearest hotel: camino real
# Ixtapa - nearest hotel: No hotel found
# Mwene-Ditu - nearest hotel: Hôtel KAMAS
# Kieta - nearest hotel: No hotel found
# Pontianak - nearest hotel: Golden Tulip Hotel
# Ruwi - nearest hotel: Sheraton Oman
# Rafaela - nearest hotel: Parra Hotel & Suites
# Alice Springs - nearest hotel: Aurora Alice Springs
# Umm Lajj - nearest hotel: No hotel found
# Morondava - nearest hotel: Hotel Sharon Menabe
# Tiznit - nearest hotel: No hotel found
# Siteki - nearest hotel: Siteki hotel
# Araripina - nearest hotel: Hotel Recanto da Serra
# Sinnamary - nearest hotel: Hôtel du fleuve
# Araouane - nearest hotel: No hotel found
# Inhambane - nearest hotel: Hotel de Inhambane
# Bull Savanna - nearest hotel: Junction Guest House
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Tual - nearest hotel: Suita
# Sarangani - nearest hotel: No hotel found
# Khed - nearest hotel: No hotel found
# Oranjestad - nearest hotel: Hotel California
# Sibu - nearest hotel: The Paramount Hotel
# Goiatuba - nearest hotel: No hotel found
# Grand Gaube - nearest hotel: Hotel Lux- Grand Gaube
# Ailigandi - nearest hotel: Akwadup Lodge
# Itarema - nearest hotel: Pousada Oásis
# Lucapa - nearest hotel: No hotel found
# Gusau - nearest hotel: No hotel found
# Sokolo - nearest hotel: Mairie de la Commune de Sokolo
# Bairiki - nearest hotel: Marry's Motel
# Marigot - nearest hotel: Centr' Hotel
# Vanimo - nearest hotel: CBC Guesthouse
# Celestun - nearest hotel: Hotel Flamingo Playa
# Bilma - nearest hotel: No hotel found
# Dubbo - nearest hotel: Blue Gum Motel
# Puerto Baquerizo Moreno - nearest hotel: Dory's House
# Ulladulla - nearest hotel: Hotel Marlin
# Bundaberg - nearest hotel: Young Australian Hotel
# Clarence Town - nearest hotel: Erringhi Hotel
# Puerto Maldonado - nearest hotel: Puerto Palmeras
# Mabaruma - nearest hotel: Monty Brooms Hotel
# Boca Do Acre - nearest hotel: No hotel found
# Kloulklubed - nearest hotel: The Adventures Inn
# Koulikoro - nearest hotel: No hotel found
# Nabire - nearest hotel: Hotel Anggrek
# Den Chai - nearest hotel: Den Chai
# Maragogi - nearest hotel: Pousada Mariluz
# Salinopolis - nearest hotel: Hotel Salinópolis
# Matara - nearest hotel: Villa Palm Breeze
# Poya - nearest hotel: No hotel found
# Nagua - nearest hotel: hotel central
# Athmallik - nearest hotel: No hotel found
# La Asuncion - nearest hotel: Hotel La Ciudad
# Balud - nearest hotel: No hotel found
# Ocos - nearest hotel: No hotel found
# Sao Francisco - nearest hotel: Hotel Atalaia
# Ca Mau - nearest hotel: Khách sạn Song Ngọc
# Chabahar - nearest hotel: هتل سپیده
# Oriximina - nearest hotel: No hotel found
# Benjamin Constant - nearest hotel: No hotel found
# Port Hedland - nearest hotel: The Esplanade Hotel
# Ahuimanu - nearest hotel: No hotel found
# Kambove - nearest hotel: No hotel found
# Graaff-Reinet - nearest hotel: Profcon Resort
# Bowen - nearest hotel: Whitsunday Sands Resort
# Auki - nearest hotel: No hotel found
# Castelo Do Piaui - nearest hotel: No hotel found
# Aloleng - nearest hotel: No hotel found
# Ipixuna - nearest hotel: No hotel found
# Natal - nearest hotel: Natal Palace Hotel
# Canutama - nearest hotel: No hotel found
# Karratha - nearest hotel: Karratha International Hotel
# Lydenburg - nearest hotel: No hotel found
# Port Augusta - nearest hotel: Hotel Commonwealth
# Gao - nearest hotel: No hotel found
# Katobu - nearest hotel: No hotel found
# Kendari - nearest hotel: City Hotel Kendari
# Akropong - nearest hotel: No hotel found
# Formosa Do Rio Preto - nearest hotel: Pousada Universo - Formosa do Rio Preto BA
# Chipinge - nearest hotel: No hotel found
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Pringsewu - nearest hotel: No hotel found
# Kabare - nearest hotel: Panorama Hotel
# Cayenne - nearest hotel: Central Hôtel
# Vieux-Habitants - nearest hotel: Gîtes "Les Cocotiers"
# Lilongwe - nearest hotel: Woodlands Lilongwe
# Lethem - nearest hotel: Hotel Amazonas
# Luanda - nearest hotel: Hotel Forum
# Dutlwe - nearest hotel: No hotel found
# Batemans Bay - nearest hotel: Esplanade Hotel
# Palauig - nearest hotel: No hotel found
# Rawson - nearest hotel: Hotel Deportivo
# Alta Floresta - nearest hotel: Villas Hotel
# Boa Vista - nearest hotel: Aipana Plaza Hotel
#                          City Country  Max Temp Current Description      Lat  \
# 0             Lazaro Cardenas      MX     72.07           clear sky  17.9583
# 1    Sao Gabriel Da Cachoeira      BR     74.10       broken clouds  -0.1303
# 3                     Rikitea      PF     76.41     overcast clouds -23.1203
# 18                  Katherine      AU     79.12     overcast clouds -14.4667
# 20                        Vao      NC     78.49     overcast clouds -22.6667
# ..                        ...     ...       ...                 ...      ...
# 708              Batemans Bay      AU     74.50    scattered clouds -35.7167
# 709                   Palauig      PH     78.57       broken clouds  15.4350
# 715                    Rawson      AR     73.94    scattered clouds -43.3002
# 718             Alta Floresta      BR     73.02     overcast clouds  -9.8756
# 720                 Boa Vista      BR     76.98           clear sky   2.8197
#
#           Lng              Hotel Name
# 0   -102.2000  Hotel Sol del Pacífico
# 1    -67.0892       Hotel Deus Me Deu
# 3   -134.9692    Chez Bianca & Benoit
# 18   132.2667          No hotel found
# 20   167.4833              Nataiwatch
# ..        ...                     ...
# 708  150.1833         Esplanade Hotel
# 709  119.9045          No hotel found
# 715  -65.1023         Hotel Deportivo
# 718  -56.0861            Villas Hotel
# 720  -60.6733      Aipana Plaza Hotel
#
# [269 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df["Hotel Name"].str.contains("No hotel found") == False]

# Display sample data
clean_hotel_df.head(10)
# Out:
#                         City Country  Max Temp Current Description      Lat  \
# 0            Lazaro Cardenas      MX     72.07           clear sky  17.9583
# 1   Sao Gabriel Da Cachoeira      BR     74.10       broken clouds  -0.1303
# 3                    Rikitea      PF     76.41     overcast clouds -23.1203
# 20                       Vao      NC     78.49     overcast clouds -22.6667
# 27                    Touros      BR     82.83    scattered clouds  -5.1989
# 30                  Cidreira      BR     72.57    scattered clouds -30.1811
# 35                 Hithadhoo      MV     83.23       broken clouds  -0.6000
# 39             Pangkalanbuun      ID     80.91     overcast clouds  -2.6833
# 41        Sao Felix Do Xingu      BR     73.29     overcast clouds  -6.6447
# 42              Puerto Ayora      EC     77.56       broken clouds  -0.7393
#
#          Lng                            Hotel Name
# 0  -102.2000                Hotel Sol del Pacífico
# 1   -67.0892                     Hotel Deus Me Deu
# 3  -134.9692                  Chez Bianca & Benoit
# 20  167.4833                            Nataiwatch
# 27  -35.4608                     Pousada Atlântico
# 30  -50.2056                         Hotel Castelo
# 35   73.0833                           Pebbles Inn
# 39  111.6167                           Hotel Tiara
# 41  -51.9950                         Hotel Terraço
# 42  -90.3518  Hostal La Mirada De Solitario George

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_data_file = "/Users/miracleonyeoziri/Documents/Bootcamp Materials/Module 6/World_Weather_Analysis/Vacation_Search/WeatherPy_vacation.csv"

# Export the clean_hotel_df into a csv
clean_hotel_df.to_csv(output_data_file)

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country", "Current Description"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)
